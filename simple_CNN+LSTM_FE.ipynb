# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install nptdms
# Out:
# Collecting nptdms
#   Downloading nptdms-1.10.0.tar.gz (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 11.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from nptdms) (2.0.2)
# Building wheels for collected packages: nptdms
#   Building wheel for nptdms (pyproject.toml) ... done
#   Created wheel for nptdms: filename=nptdms-1.10.0-py3-none-any.whl size=108456 sha256=c1fee5688939b281a0c2d1388f695199d1a1f83bcfa6cd3deedc7e1315f43310
#   Stored in directory: /root/.cache/pip/wheels/1b/4b/17/21e8b03b37ea51ce7ec9f5570cdf0decca93f537d61c06880f
# Successfully built nptdms
# Installing collected packages: nptdms
# Successfully installed nptdms-1.10.0

# %% [markdown]
# ## CNN+LSTM

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, concatenate, LSTM, Dense, Dropout, Flatten, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import numpy as np
import os
from scipy.fft import rfft
import pywt
from nptdms import TdmsFile
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.optimizers import Adam
import joblib

import pandas as pd
from sklearn.linear_model import LinearRegression

from tensorflow.keras import regularizers
from tqdm import tqdm

# %% [markdown]
# 데이터 전처리 파이프라인

# %%
def load_tdms_file(file_path):
    tdms_file = TdmsFile.read(file_path)

    group_name_vibration = tdms_file.groups()[0].name
    group_name_operation = tdms_file.groups()[1].name

    vib_channels = tdms_file[group_name_vibration].channels()
    vib_data = {ch.name.strip(): ch.data for ch in vib_channels}

    operation_channels = tdms_file[group_name_operation].channels()
    operation_data = {ch.name.strip(): ch.data for ch in operation_channels}

    return vib_data, operation_data

# %% [markdown]
# ### operation

# %% [markdown]
# RUL 라벨링

# %%
# tdms 파일에서 operation data 불러오기
def load_summary_from_tdms(train_root, target_folders):
    summary = {}

    for folder in target_folders:
        folder_path = os.path.join(train_root, folder)
        tdms_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".tdms")])

        records = []

        for idx, tdms_file in enumerate(tdms_files):
            file_path = os.path.join(folder_path, tdms_file)
            _, operation_data = load_tdms_file(file_path)

            time_sec = idx * 600  # 10분 간격

            record = {
                "time_sec": time_sec,
                "TC SP Front[℃]": operation_data["TC SP Front[℃]"][0],
                "TC SP Rear[℃]": operation_data["TC SP Rear[℃]"][0],
                "Torque[Nm]": operation_data["Torque[Nm]"][0],
                "file_name": os.path.splitext(tdms_file)[0],  # 확장자 제거
                "folder": folder
            }
            records.append(record)

        df = pd.DataFrame(records)
        summary[folder] = df

    return summary

# 중단 조건 도달 여부
def check_stop_condition_met(df):
    # 조건 1: Torque ≤ -17 Nm
    torque_stop = df["Torque[Nm]"] <= -17

    # 조건 2: TC SP Front ≥ 200 or TC SP Rear ≥ 200
    temp_stop = (df["TC SP Front[℃]"] >= 200) | (df["TC SP Rear[℃]"] >= 200)

    # 어느 하나라도 만족하면 중단 조건 도달
    stop_condition_met = (torque_stop | temp_stop).any()
    return stop_condition_met

# 중단 조건에 도달한 data point가 없을 경우
# 선형 회귀 함수
def estimate_rul_from_temp_time_based(temp_values, start_index, interval_sec=600, file_id="Sample"):
    n = len(temp_values)
    x = np.arange(start_index, start_index + n) * interval_sec
    y = np.array(temp_values)

    x_reshaped = x.reshape(-1, 1)
    model = LinearRegression().fit(x_reshaped, y)
    m = model.coef_[0]
    c = model.intercept_

    if m <= 0:
        print(f"[{file_id}] Warning: Temperature is not increasing (slope ≤ 0).")
        return None, None

    estimated_failure_time_sec = (200 - c) / m
    rul_seconds = estimated_failure_time_sec - x[-1]

    if estimated_failure_time_sec < x[-1] or rul_seconds < 0:
        print(f"[{file_id}] Warning: Predicted failure is before current time. Invalid regression.")
        return None, None

    return estimated_failure_time_sec, rul_seconds

# Front, Rear 선택 함수
def choose_temp_column_closer_to_200(df, front_col, rear_col):
    # 마지막 측정값 기준으로 200도와의 절대 차이 비교 후 Front, Rear 선택
    front_diff = abs(df[front_col].iloc[-1] - 200)
    rear_diff = abs(df[rear_col].iloc[-1] - 200)
    if front_diff <= rear_diff:
        return front_col
    else:
        return rear_col

# 3/5 points 선택 함수
def select_best_rul_with_temp_choice(df, estimation_targets, train_id, threshold_r2=0.85, interval_sec=600):
    front_col, rear_col = estimation_targets[train_id]
    target_col = choose_temp_column_closer_to_200(df, front_col, rear_col)

    results = []

    for n in [3, 5]:
        temp_values = df[target_col].values[-n:]
        start_index = len(df) - n
        x = np.arange(start_index, start_index + n) * interval_sec
        y = np.array(temp_values)

        model = LinearRegression().fit(x.reshape(-1, 1), y)
        r2 = model.score(x.reshape(-1, 1), y)

        est_time, rul = estimate_rul_from_temp_time_based(
            temp_values=temp_values,
            start_index=start_index,
            interval_sec=interval_sec,
            file_id=f"{train_id}_{target_col}_last{n}"
        )

        if est_time is not None and rul is not None:
            results.append((r2, est_time, rul, n))

    # 우선 R²가 threshold 이상인 것 중 R²가 높은 것 선택
    filtered = [res for res in results if res[0] >= threshold_r2]

    if filtered:
        best = max(filtered, key=lambda x: x[0])
    elif results:
        best = max(results, key=lambda x: x[0])
    else:
        print(f"[{train_id}] No valid regression results.")
        return None, None, None

    r2, est_time, rul, used_n = best
    print(f"[{train_id} | {target_col}] Selected {used_n} points (R² = {r2:.4f}) → RUL = {rul:.1f} sec")
    return est_time, rul, used_n

def label_rul_by_estimation(summary, estimation_targets, threshold_r2=0.85, interval_sec=600):
    """
    중단 조건을 만족하지 않은 데이터셋에 대해 회귀 기반으로 RUL을 추정하여 라벨링합니다.
    입력 summary는 {TrainID: DataFrame} 형식입니다.
    """
    for train_id in estimation_targets.keys():
        df = summary[train_id]

        # 1. 회귀 기반으로 RUL 추정
        est_time, rul, used_n = select_best_rul_with_temp_choice(df,estimation_targets, train_id, threshold_r2, interval_sec)

        if est_time is None:
            print(f"[{train_id}] RUL 예측 실패로 라벨링하지 않음.")
            continue

        # 2. 라벨링
        df = df.copy()
        df['time_sec'] = np.arange(len(df)) * interval_sec
        df['RUL_sec'] = (est_time - df['time_sec']).clip(lower=0)

        # 3. 업데이트
        summary[train_id] = df

    return summary

# 중단 조건에 도달한 data point가 있을 경우
def label_rul_by_stopping(summary, interval_sec=600):
    """
    중단 조건 시점에 따라 RUL을 라벨링합니다.
    입력 summary는 {TrainID: DataFrame} 형식입니다.
    """
    for train_id, df in summary.items():
        df = df.copy()

        # 조건 1: Torque ≤ -17
        torque_stop_idx = df.index[df["Torque[Nm]"] <= -17]

        # 조건 2: TC SP Front ≥ 200 or TC SP Rear ≥ 200
        temp_stop_idx = df.index[
            (df["TC SP Front[℃]"] >= 200) | (df["TC SP Rear[℃]"] >= 200)
        ]

        # 가장 빠른 중단 시점 찾기
        all_stop_indices = pd.concat([pd.Series(torque_stop_idx), pd.Series(temp_stop_idx)]).sort_values()

        if not all_stop_indices.empty:
            failure_idx = all_stop_indices.iloc[0]
            failure_time_sec = df.loc[failure_idx, "time_sec"]
        else:
            failure_time_sec = df["time_sec"].max()

        # 라벨링
        df["RUL_sec"] = (failure_time_sec - df["time_sec"]).clip(lower=0)

        # 업데이트
        summary[train_id] = df

    return summary


def label_rul_pipeline(summary, estimation_targets, threshold_r2=0.85, interval_sec=600):
    """
    중단 조건 충족 여부에 따라 적절한 라벨링 방식 적용.
    - 중단 조건 만족: 조건 기반 라벨링
    - 중단 조건 불만족: 회귀 기반 추정 라벨링
    - estimation_targets: 중단 조건 불만족으로 회귀 예측이 필요한 데이터셋 dict
    """
    for train_id, df in summary.items():
      if check_stop_condition_met(df):
          updated = label_rul_by_stopping({train_id: df}, interval_sec=interval_sec)
          summary[train_id] = updated[train_id]
          print(f"[{train_id}] 조건 기반 라벨링 완료.")
      elif train_id in estimation_targets:
          updated = label_rul_by_estimation({train_id: df}, {train_id: estimation_targets[train_id]}, threshold_r2, interval_sec)
          summary[train_id] = updated[train_id]
          print(f"[{train_id}] 회귀 기반 라벨링 완료.")
      else:
          print(f"[{train_id}] 회귀 대상 정보가 없어 라벨링 생략.")

    return summary

def get_train_folders(train_root):
    all_folders = os.listdir(train_root)
    train_folders = [f for f in all_folders if f.lower().startswith("train") and os.path.isdir(os.path.join(train_root, f))]
    return sorted(train_folders)

# %% [markdown]
# slope 추가

# %%
# slope 계산
def compute_slope_feature(df, column_name, N, interval_sec=600):
    """
    주어진 데이터프레임에서 column_name에 대한 slope 피처 계산
    """
    slope_col = f"{column_name}_Slope_{N}cycle"
    slopes = [np.nan] * len(df)
    for i in range(N, len(df)):
        delta_y = df[column_name].iloc[i] - df[column_name].iloc[i - N]
        delta_x = df["time_sec"].iloc[i] - df["time_sec"].iloc[i - N]
        slopes[i] = delta_y / delta_x
    df[slope_col] = slopes
    return df

# TC_slope x Torque_slope
def compute_combined_slope(df, temp_col, torque_col, N):
    """
    온도 slope와 토크 slope의 곱 (복합 지표)
    """
    temp_slope_col = f"{temp_col}_Slope_{N}cycle"
    torque_slope_col = f"{torque_col}_Slope_{N}cycle"
    combined_col = f"Combined_Slope_{N}cycle"
    if temp_slope_col in df.columns and torque_slope_col in df.columns:
        df[combined_col] = df[temp_slope_col] * df[torque_slope_col]
    return df

def apply_slope_features(summary, estimation_targets, N_list=[3, 5], interval_sec=600):
    """
    모든 summary 데이터프레임에 대해 slope 및 combined slope 피처 추가
    """
    for train_id, df in summary.items():
        front_col, rear_col = estimation_targets.get(train_id, ("TC SP Front[℃]", "TC SP Rear[℃]"))
        df = df.copy()
        for N in N_list:
            df = compute_slope_feature(df, "Torque[Nm]", N, interval_sec)
            df = compute_slope_feature(df, front_col, N, interval_sec)
            df = compute_slope_feature(df, rear_col, N, interval_sec)
            df = compute_combined_slope(df, front_col, "Torque[Nm]", N)
            df = compute_combined_slope(df, rear_col, "Torque[Nm]", N)

        df = df.dropna().reset_index(drop=True)  # NaN 행 제거
        summary[train_id] = df
    return summary

# %% [markdown]
# 병합을 위한 expand summary

# %%
# vibration data와 합치기 위해 펼치기
def expand_summary_to_windows(summary_df, window_size=25600, overlap=0.5, fixed_total_samples=256000):
    step = int(window_size * (1 - overlap))
    num_windows = (fixed_total_samples - window_size) // step + 1
    expanded_rows = []

    for idx, row in summary_df.iterrows():
        file_name = row.get("file_name", None)
        folder = row.get("folder", None)

        if file_name is None:
            raise ValueError("summary_df에 'file_name' 컬럼이 없습니다.")
        if folder is None:
            raise ValueError("summary_df에 'folder' 컬럼이 없습니다.")

        for w in range(num_windows):
            new_row = row.copy()
            new_row["window_index"] = w
            new_row["file_name"] = file_name
            new_row["folder"] = folder
            expanded_rows.append(new_row)

    expanded_df = pd.DataFrame(expanded_rows)
    return expanded_df

# %% [markdown]
# RUL 라벨링, slope 수행

# %%
def full_pipeline_with_slope_and_rul(train_root, interval_sec=600, threshold_r2=0.85, N_list=[3, 5]):
    train_folders = get_train_folders(train_root)
    targets = {folder: ("TC SP Front[℃]", "TC SP Rear[℃]") for folder in train_folders}

    summary = load_summary_from_tdms(train_root, train_folders)

    estimation_targets = {
        train_id: targets[train_id]
        for train_id, df in summary.items()
        if not check_stop_condition_met(df)
    }

    summary = label_rul_pipeline(summary, estimation_targets, threshold_r2=threshold_r2, interval_sec=interval_sec)
    summary = apply_slope_features(summary, targets, N_list=N_list, interval_sec=interval_sec)

    return summary

# %%
train_root = "/content/drive/MyDrive/KSPHM-data-challenge/Train Set"
summary = full_pipeline_with_slope_and_rul(train_root, interval_sec=600, threshold_r2=0.85, N_list=[3, 5])

# summary는 dict이므로 하나의 DataFrame으로 병합
summary_df = pd.concat(
    [df.assign(folder=train_id) for train_id, df in summary.items()],
    ignore_index=True
)

# 윈도우 단위로 확장
summary_expanded = expand_summary_to_windows(summary_df)
# Out:
# [Train1] 조건 기반 라벨링 완료.
# [Train2 | TC SP Front[℃]] Selected 5 points (R² = 0.9353) → RUL = 215.7 sec
# [Train2] 회귀 기반 라벨링 완료.
# [Train3 | TC SP Front[℃]] Selected 3 points (R² = 0.7762) → RUL = 196.4 sec
# [Train3] 회귀 기반 라벨링 완료.
# [Train4] 조건 기반 라벨링 완료.
# [Train5] 조건 기반 라벨링 완료.
# [Train6 | TC SP Rear[℃]] Selected 5 points (R² = 0.7887) → RUL = 614.9 sec
# [Train6] 회귀 기반 라벨링 완료.
# [Train7] 조건 기반 라벨링 완료.
# [Train8] 조건 기반 라벨링 완료.

# %% [markdown]
# ### vibration

# %% [markdown]
# WPT+FFT 및 고장 주파수 기반 FFT 피처

# %%
# 고장 주파수 정의 (단위: Hz)
FAULT_FREQUENCIES = {
    "BPFI": 140,
    "BPFO": 93,
    "BSF": 78,
    "Cage": 6.7
}

# 슬라이딩 윈도우 생성
# (window_size 샘플, overlap 비율)
def sliding_window(data, window_size=25600, overlap=0.5):
    step = int(window_size * (1 - overlap))
    return np.array([
        data[start:start + window_size]
        for start in range(0, len(data) - window_size + 1, step)
    ])  # (윈도우 수, window_size, 채널 수)

# WPT+FFT 특징 추출 함수
def extract_wpt_fft_features(signal, wavelet='db4', level=3, top_k=10):
    wp = pywt.WaveletPacket(data=signal, wavelet=wavelet, mode='symmetric', maxlevel=level)
    nodes = [node.path for node in wp.get_level(level, 'freq')]
    features = []
    for node in nodes:
        coeffs = wp[node].data
        fft_vals = np.abs(rfft(coeffs))
        top_features = np.sort(fft_vals)[-top_k:]
        features.extend(top_features)
    return np.array(features)  # (노드 수 × top_k, )

# TDMS 파일 경로로부터 진동 데이터 읽어, 윈도우별 WPT+FFT 특징 추출 함수
def extract_vibration_array_with_features(file_path, window_size=25600, overlap=0.5, wavelet='db4', level=3, top_k=10):
    vib_data, _ = load_tdms_file(file_path)
    channels = ["CH1", "CH2", "CH3", "CH4"]
    vib_arrays = [vib_data[ch] for ch in channels if ch in vib_data]
    vib_matrix = np.vstack(vib_arrays).T  # (샘플 수, 4)

    windows = sliding_window(vib_matrix, window_size=window_size, overlap=overlap)  # (윈도우 수, window_size, 4)
    all_features = []

    for window in windows:
        window_features = []
        for ch_idx in range(window.shape[1]):
            signal = window[:, ch_idx]
            feat = extract_wpt_fft_features(signal, wavelet=wavelet, level=level, top_k=top_k)
            window_features.extend(feat)
        all_features.append(window_features)

    return np.array(all_features)  # (윈도우 수, 채널 수 * 특징 수)

# 고장 주파수 기반 FFT 특징 추출
# 단일 채널 고장 주파수 특징 추출(FFT)
def extract_fault_frequency_features(signal, Fs, fault_freqs=FAULT_FREQUENCIES, bandwidth=5):
    N = len(signal)
    freqs = np.fft.fftfreq(N, d=1/Fs)[:N//2]
    fft_magnitude = np.abs(np.fft.fft(signal))[:N//2]

    features = {}

    for fault_name, f_center in fault_freqs.items():
        lower = f_center - bandwidth
        upper = f_center + bandwidth
        band_mask = (freqs >= lower) & (freqs <= upper)
        band_energy = np.sum(fft_magnitude[band_mask] ** 2)

        if np.any(band_mask):
            peak_idx = np.argmax(fft_magnitude[band_mask])
            band_mags = fft_magnitude[band_mask]
            peak_amp = band_mags[peak_idx]
        else:
            peak_amp = 0.0

        features[f"{fault_name}_Energy"] = band_energy
        features[f"{fault_name}_Peak_Amplitude"] = peak_amp

    return features


# TDMS 파일 단일 처리, 멀티 채널 고장 주파수 특징 추출
def extract_fault_features_from_tdms(vib_data, duration_sec=10, bandwidth=5):
    """
    TDMS 진동 데이터(CH1~CH4)에서 고장 주파수 특징 추출
    - vib_data: TDMS에서 읽은 dict ({"CH1": array, ...})
    - duration_sec: 시퀀스 길이 (기본 10초)
    """
    features = {}
    channels = ["CH1", "CH2", "CH3", "CH4"]

    # 샘플 수 → Fs 계산
    sample_counts = [len(vib_data[ch]) for ch in channels if ch in vib_data]
    if not sample_counts:
        raise ValueError("No valid vibration channels found.")
    N = sample_counts[0]
    Fs = N / duration_sec  # 샘플링 주파수

    for ch in channels:
        if ch not in vib_data:
            continue
        signal = vib_data[ch]
        fault_feats = extract_fault_frequency_features(signal, Fs, bandwidth=bandwidth)
        for k, v in fault_feats.items():
            features[f"{ch}_{k}"] = v

    return features

# WPT+FFT 윈도우별 특징 추출
def process_all_train_folders(base_path, folder_names):
    all_feature_rows = []

    for folder_name in folder_names:
        folder_path = os.path.join(base_path, folder_name)
        tdms_files = sorted([f for f in os.listdir(folder_path) if f.endswith('.tdms')])

        for tdms_file in tdms_files:
            file_path = os.path.join(folder_path, tdms_file)
            features = extract_vibration_array_with_features(file_path)

            for i, feature in enumerate(features):
                all_feature_rows.append({
                    'file_name': tdms_file,
                    'window_index': i,
                    'features': feature,
                    'folder': folder_name
                })

    return pd.DataFrame(all_feature_rows)

# 모든 train 폴더 적용
def extract_fault_features_all(train_root, target_folders=None, bandwidth=5):
    """
    Train Set 전체 TDMS 파일에 대해 고장 주파수 기반 FFT 피처 추출
    """
    if target_folders is None:
        target_folders = sorted(os.listdir(train_root))

    all_records = []

    for folder in tqdm(target_folders, desc="Extracting fault features"):
        folder_path = os.path.join(train_root, folder)
        tdms_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".tdms")])

        for tdms_file in tdms_files:
            file_path = os.path.join(folder_path, tdms_file)
            try:
                vib_data, _ = load_tdms_file(file_path)
                features = extract_fault_features_from_tdms(vib_data, bandwidth=bandwidth)
                features["folder"] = folder
                features["file_name"] = tdms_file.replace('.tdms', '')
                all_records.append(features)
            except Exception as e:
                print(f"Failed to process {file_path}: {e}")

    df = pd.DataFrame(all_records)
    return df

# 파일 단위 summary로 변환(평균, 표준편차)
def summarize_window_features_compact(features_df):
    summary_records = []

    for (folder, file_name), group in features_df.groupby(['folder', 'file_name']):
        feature_array = np.stack(group['features'].values)  # (윈도우 수, 피처 수)
        feature_mean = np.mean(feature_array, axis=0)
        feature_std = np.std(feature_array, axis=0)

        record = {
            'folder': folder,
            'file_name': file_name,
            'WPTFFT_Feature_mean': feature_mean,
            'WPTFFT_Feature_std': feature_std,
        }

        summary_records.append(record)

    return pd.DataFrame(summary_records)

# %%
# --- 설정값 ---
base_path = "/content/drive/MyDrive/KSPHM-data-challenge/Train Set"
folder_names = [f"Train{i}" for i in range(1, 9)]  # Train1 ~ Train8

# --- WPT+FFT 윈도우 특징 추출 수행 ---
features_df = process_all_train_folders(base_path, folder_names)
features_df['file_name'] = features_df['file_name'].str.replace(r'\.tdms$', '', regex=True)
# Out:
# Extracting fault features: 100%|██████████| 8/8 [00:00<00:00, 164.97it/s]
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325122639.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325123839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325124839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325125839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325130839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325131839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325132839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325133839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325134839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325135839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325140839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325141839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325142839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325143839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325144839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325145839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325150839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325151839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325152839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325153839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325154839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325155839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325160839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325161839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325162839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325163839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325164839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325165839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325170839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325171839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325172839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325173839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325174839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325175839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325180839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325181839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325182839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325183839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325184839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325185839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325190839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325191839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325192839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325193839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325194839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325195839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325200839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325201839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325202839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325203839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325204839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325205839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325210839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325211839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325212839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325213839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325214839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325215839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325220839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325221839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325222839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325223839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325224839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325225839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325230839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325231839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325232839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325233839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325234839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160325235839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326000839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326001839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326002839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326003839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326004839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326005839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326010839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326011839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326012839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326013839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326014839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326015839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326020839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326021839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326022839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326023839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326024839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326025839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326030839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326031839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326032839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326033839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326034839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train1/modified_KIMM Simulator_KIMM Bearing Test_20160326035839.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330183757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330184757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330185757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330190757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330191757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330192757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330193757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330194757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330195757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330200757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330201757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330202757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330203757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330204757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330205757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330210757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330211757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330212757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330213757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330214757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330215757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330220757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330221757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330222757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330223757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330224757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330225757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330230757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330231757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330232757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330233757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330234757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160330235757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331000757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331001757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331002757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331003757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331004757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331005757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331010757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331011757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331012757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331013757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331014757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331015757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331020757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331021757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331022757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331023757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331024757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331025757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331030757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331031757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331032757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331033757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331034757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331035757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331040757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331041757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331042757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331043757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331044757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331045757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331050757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331051757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331052757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331053757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331054757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331055757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331060757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331061757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331062757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331063757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331064757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331065757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331070757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331071757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331072757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331073757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331074757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331075757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331080757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331081757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331082757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331083757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331084757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331085757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331090757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331091757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331092757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331093757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331094757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331095757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331100757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331101757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331102757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331103757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331104757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331105757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331110757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331111757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331112757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331113757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331114757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331115757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331120757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331121757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331122757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331123757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331124757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331125757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331130757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331131757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331132757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331133757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331134757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331135757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331140757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331141757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331142757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331143757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331144757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331145757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331150757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331151757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331152757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331153757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331154757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331155757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331160757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331161757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331162757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331163757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331164757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331165757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331170757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331171757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331172757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331173757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331174757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331175757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331180757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331181757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331182757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331183757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331184757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331185757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331190757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train2/modified_KIMM Simulator_KIMM Bearing Test_20160331191757.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401194507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401195507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401200507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401201507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401202507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401203507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401204507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401205507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401210507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401211507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401212507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401213507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401214507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401215507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401220507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401221507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401222507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401223507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401224507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401225507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401230507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401231507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401232507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401233507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401234507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160401235507.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train3/modified_KIMM Simulator_KIMM Bearing Test_20160402000507.tdms: No valid vibration channels found.
# ...
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608202522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608203522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608204522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608205522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608210522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608211522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608212522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608213522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608214522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608215522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608220522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608221522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608222522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608223522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608224522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608225522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608230522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608231522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608232522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608233522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608234522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160608235522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609000522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609001522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609002522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609003522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609004522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609005522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609010522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609011522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609012522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609013522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609014522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609015522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609020522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609021522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609022522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609023522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609024522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609025522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609030522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609031522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609032522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609033522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609034522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609035522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609040522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609041522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609042522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609043522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609044522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609045522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609050522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609051522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609052522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609053522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609054522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609055522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609060522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609061522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609062522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609063522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609064522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609065522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609070522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609071522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609072522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609073522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609074522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609075522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609080522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609081522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609082522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609083522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609084522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609085522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609090522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609091522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609092522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609093522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609094522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609095522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609100522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609101522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609102522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609103522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609104522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609105522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609110522.tdms: No valid vibration channels found.
# Failed to process /content/drive/MyDrive/KSPHM-data-challenge/Train Set/Train8/modified_KIMM Simulator_KIMM Bearing Test_20160609111522.tdms: No valid vibration channels found.

# %%
wptfft_summary_df = summarize_window_features_compact(features_df)

# %%
# --- 고장 주파수 FFT 특징 추출 ---
fault_summary_df = extract_fault_features_all(base_path, folder_names, bandwidth=5)
# Out:
# Extracting fault features: 100%|██████████| 8/8 [01:53<00:00, 14.18s/it]

# %%
print("wptfft_summary_df columns:", wptfft_summary_df.columns.tolist())
print("fault_summary_df columns:", fault_summary_df.columns.tolist())
# Out:
# wptfft_summary_df columns: ['folder', 'file_name', 'WPTFFT_Feature_mean', 'WPTFFT_Feature_std']
# fault_summary_df columns: ['CH1_BPFI_Energy', 'CH1_BPFI_Peak_Amplitude', 'CH1_BPFO_Energy', 'CH1_BPFO_Peak_Amplitude', 'CH1_BSF_Energy', 'CH1_BSF_Peak_Amplitude', 'CH1_Cage_Energy', 'CH1_Cage_Peak_Amplitude', 'CH2_BPFI_Energy', 'CH2_BPFI_Peak_Amplitude', 'CH2_BPFO_Energy', 'CH2_BPFO_Peak_Amplitude', 'CH2_BSF_Energy', 'CH2_BSF_Peak_Amplitude', 'CH2_Cage_Energy', 'CH2_Cage_Peak_Amplitude', 'CH3_BPFI_Energy', 'CH3_BPFI_Peak_Amplitude', 'CH3_BPFO_Energy', 'CH3_BPFO_Peak_Amplitude', 'CH3_BSF_Energy', 'CH3_BSF_Peak_Amplitude', 'CH3_Cage_Energy', 'CH3_Cage_Peak_Amplitude', 'CH4_BPFI_Energy', 'CH4_BPFI_Peak_Amplitude', 'CH4_BPFO_Energy', 'CH4_BPFO_Peak_Amplitude', 'CH4_BSF_Energy', 'CH4_BSF_Peak_Amplitude', 'CH4_Cage_Energy', 'CH4_Cage_Peak_Amplitude', 'folder', 'file_name']

# %%
# --- 두 summary 병합 ---
summary_df = pd.merge(wptfft_summary_df, fault_summary_df, on=['folder', 'file_name'], how='inner')

print(f"요약된 파일 수: {len(summary_df)}")
print(f"총 윈도우 수: {len(features_df)}")
# Out:
# 요약된 파일 수: 1229
# 총 윈도우 수: 23351

# %% [markdown]
# ### 병합

# %%
print("summary_expanded columns:", summary_expanded.columns.tolist())
print("features_df columns:", features_df.columns.tolist())
# Out:
# summary_expanded columns: ['time_sec', 'TC SP Front[℃]', 'TC SP Rear[℃]', 'Torque[Nm]', 'file_name', 'folder', 'RUL_sec', 'Torque[Nm]_Slope_3cycle', 'TC SP Front[℃]_Slope_3cycle', 'TC SP Rear[℃]_Slope_3cycle', 'Combined_Slope_3cycle', 'Torque[Nm]_Slope_5cycle', 'TC SP Front[℃]_Slope_5cycle', 'TC SP Rear[℃]_Slope_5cycle', 'Combined_Slope_5cycle', 'window_index']
# features_df columns: ['file_name', 'window_index', 'features', 'folder']

# %%
# 1) 먼저 features_df와 summary_expanded가 모두 만들어졌다고 가정
# 2) key: ['folder', 'file_name', 'window_index']

merged_df = pd.merge(
    summary_expanded,
    features_df,
    on=['folder', 'file_name', 'window_index'],
    how='inner'  # 윈도우 단위로 완전히 겹치는 데이터만 남음
)

print("병합된 데이터 개수:", len(merged_df))
print(merged_df.columns)
# Out:
# 병합된 데이터 개수: 22591
# Index(['time_sec', 'TC SP Front[℃]', 'TC SP Rear[℃]', 'Torque[Nm]',
#        'file_name', 'folder', 'RUL_sec', 'Torque[Nm]_Slope_3cycle',
#        'TC SP Front[℃]_Slope_3cycle', 'TC SP Rear[℃]_Slope_3cycle',
#        'Combined_Slope_3cycle', 'Torque[Nm]_Slope_5cycle',
#        'TC SP Front[℃]_Slope_5cycle', 'TC SP Rear[℃]_Slope_5cycle',
#        'Combined_Slope_5cycle', 'window_index', 'features'],
#       dtype='object')

# %% [markdown]
# ### 데이터 로드

# %%
# --- 설정값 ---
data_dir = "Train Set"
window_size = 25600
overlap = 0.5
wavelet = 'db4'
level = 3
top_k = 10
sampling_rate = 25600
step = int(window_size * (1 - overlap))

X = np.stack(merged_df['features'].values)
X = X[..., np.newaxis]

y = merged_df['RUL_sec'].values

# --- 데이터 스케일링 ---
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()

# X는 2D 배열이어야 하므로 reshape 후 스케일링
samples, feat_dim, channels = X.shape
X_reshaped = X.reshape(samples, feat_dim * channels)  # (samples, feat_dim*channels)
X_scaled = X_scaler.fit_transform(X_reshaped)

# y는 2D로 만들어서 스케일링
y_scaled = y_scaler.fit_transform(y.reshape(-1,1))

# 다시 모델 입력에 맞게 reshape
X_train_final = X_scaled.reshape(samples, feat_dim, channels)
y_train_final = y_scaled

print(f"X_train_final shape: {X_train_final.shape}, y_train_final shape: {y_train_final.shape}")
# Out:
# X_train_final shape: (22591, 320, 1), y_train_final shape: (22591, 1)

# %%
import joblib


# 저장 경로
scaler_dir = "/content/drive/MyDrive/KSPHM-data-challenge/scalers"

# 저장
joblib.dump(X_scaler, os.path.join(scaler_dir, "X_scaler.pkl"))
joblib.dump(y_scaler, os.path.join(scaler_dir, "y_scaler.pkl"))
# Out:
# ['/content/drive/MyDrive/KSPHM-data-challenge/scalers/y_scaler.pkl']

# %% [markdown]
# ### CNN+LSTM

# %%
from tensorflow.keras import regularizers

# --- 단일 Conv1D + LSTM 모델 정의 ---
def simplified_conv1d_lstm_model(input_shape):
    # input_shape는 (total_features_per_window, 1)이 됩니다. (예: (329, 1))
    input_layer = Input(shape=(input_shape[0], 1))

    # 단일 Conv1D 레이어
    x = Conv1D(filters=16, kernel_size=8, strides=1, padding='valid', activation='relu', kernel_regularizer=regularizers.l2(0.001))(input_layer)
    x = MaxPooling1D(pool_size=2, padding='valid')(x)
    x = Dropout(0.15)(x)
    x = Conv1D(filters=8, kernel_size=4, strides=1, padding='valid', activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
    x = MaxPooling1D(pool_size=2, padding='valid')(x)

    # GlobalMaxPooling1D 또는 Flatten 후 Reshape
    x_pooled = tf.keras.layers.GlobalMaxPooling1D()(x)

    # LSTM 입력은 3D (batch, timesteps, features)
    # 현재 x_pooled는 2D (batch, features) 이므로 timesteps=1 로 Reshape
    lstm_input = Reshape((1, x_pooled.shape[-1]))(x_pooled) # x_pooled.shape[-1]이 Conv1D 출력 features

    ## LSTM ##
    lstm_out = LSTM(32, return_sequences=False)(lstm_input) # LSTM 유닛 수 조절 가능
    dropout = Dropout(0.4)(lstm_out) # Dropout 비율 조절 가능

    # 출력층 (잔존 수명 예측: 회귀 문제 → 1차원 출력)
    output = Dense(1, activation='linear')(dropout)

    # 모델 정의
    model = Model(inputs=input_layer, outputs=output)
    return model

# %% [markdown]
# 학습

# %%
input_shape = X_train_final.shape[1:] # (total_features, 1)

model = simplified_conv1d_lstm_model(input_shape)

custom_adam_optimizer_1 = Adam(learning_rate=0.0001)
model.compile(optimizer=custom_adam_optimizer_1, loss='mse')
model.summary() # 모델 요약 출력

# 콜백 설정
early_stop = EarlyStopping(patience=7, restore_best_weights=True, monitor='val_loss')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=0.00001, verbose=1)

history = model.fit(
    X_train_final, y_train_final,
    batch_size=32,
    epochs=100,
    validation_split=0.1,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 320, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 313, 16)        │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 156, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 156, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 153, 8)         │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 76, 8)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d_3          │ (None, 8)              │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 1, 8)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │         5,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,945 (23.22 KB)
#  Trainable params: 5,945 (23.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.1693 - val_loss: 0.0652 - learning_rate: 1.0000e-04
# Epoch 2/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0934 - val_loss: 0.0734 - learning_rate: 1.0000e-04
# Epoch 3/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0715 - val_loss: 0.0569 - learning_rate: 1.0000e-04
# Epoch 4/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0612 - val_loss: 0.0650 - learning_rate: 1.0000e-04
# Epoch 5/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0574 - val_loss: 0.0659 - learning_rate: 1.0000e-04
# Epoch 6/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0555 - val_loss: 0.0785 - learning_rate: 1.0000e-04
# Epoch 7/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0531 - val_loss: 0.0898 - learning_rate: 1.0000e-04
# Epoch 8/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0514 - val_loss: 0.0997 - learning_rate: 1.0000e-04
# Epoch 9/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0501 - val_loss: 0.1095 - learning_rate: 1.0000e-04
# Epoch 10/100
# 654/657 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0480
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0480 - val_loss: 0.1093 - learning_rate: 1.0000e-04

# %% [markdown]
# 시각화

# %%
# --- 결과 시각화 ---
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('MCNN_LSTM Train Loss with RUL Prediction')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### MLP

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras import regularizers

def simple_mlp_model(input_shape):
    input_layer = Input(shape=(input_shape,))
    x = Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001))(input_layer)
    x = Dropout(0.3)(x)
    x = Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
    x = Dropout(0.2)(x)
    x = Dense(16, activation='relu')(x)
    output = Dense(1, activation='linear')(x)

    model = Model(inputs=input_layer, outputs=output)
    return model

# %%
# 원본 feature와 target
X = np.stack(merged_df['features'].values)  # shape: (num_samples, num_features)
y = merged_df['RUL_sec'].values             # shape: (num_samples,)

# 스케일링
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()

X_scaled = X_scaler.fit_transform(X)
y_scaled = y_scaler.fit_transform(y.reshape(-1, 1))

# MLP는 2D 입력을 받음 → reshape 불필요
X_train_final = X_scaled                    # shape: (samples, features)
y_train_final = y_scaled                    # shape: (samples, 1)

print("MLP용 X_train shape:", X_train_final.shape)
print("MLP용 y_train shape:", y_train_final.shape)
# Out:
# MLP용 X_train shape: (23351, 320)
# MLP용 y_train shape: (23351, 1)

# %%
model = simple_mlp_model(input_shape=X_train_final.shape[1])
model.compile(optimizer='adam', loss='mse')
model.summary()

early_stop = EarlyStopping(patience=7, restore_best_weights=True, monitor='val_loss')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-5, verbose=1)

history = model.fit(
    X_train_final, y_train_final,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 320)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │        20,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,169 (90.50 KB)
#  Trainable params: 23,169 (90.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.1476 - val_loss: 0.1911 - learning_rate: 0.0010
# Epoch 2/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0300 - val_loss: 0.1554 - learning_rate: 0.0010
# Epoch 3/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0154 - val_loss: 0.1809 - learning_rate: 0.0010
# Epoch 4/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0120 - val_loss: 0.1573 - learning_rate: 0.0010
# Epoch 5/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0111 - val_loss: 0.1279 - learning_rate: 0.0010
# Epoch 6/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0099 - val_loss: 0.1269 - learning_rate: 0.0010
# Epoch 7/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0101 - val_loss: 0.1781 - learning_rate: 0.0010
# Epoch 8/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0097 - val_loss: 0.1760 - learning_rate: 0.0010
# Epoch 9/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0100 - val_loss: 0.1157 - learning_rate: 0.0010
# Epoch 10/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0097 - val_loss: 0.1126 - learning_rate: 0.0010
# Epoch 11/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0102 - val_loss: 0.1213 - learning_rate: 0.0010
# Epoch 12/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0100 - val_loss: 0.1285 - learning_rate: 0.0010
# Epoch 13/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0101 - val_loss: 0.1022 - learning_rate: 0.0010
# Epoch 14/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0094 - val_loss: 0.1239 - learning_rate: 0.0010
# Epoch 15/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0099 - val_loss: 0.1113 - learning_rate: 0.0010
# Epoch 16/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0097 - val_loss: 0.1357 - learning_rate: 0.0010
# Epoch 17/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0090 - val_loss: 0.0913 - learning_rate: 0.0010
# Epoch 18/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0092 - val_loss: 0.1158 - learning_rate: 0.0010
# Epoch 19/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0096 - val_loss: 0.1050 - learning_rate: 0.0010
# Epoch 20/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0094 - val_loss: 0.0735 - learning_rate: 0.0010
# Epoch 21/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0099 - val_loss: 0.0844 - learning_rate: 0.0010
# Epoch 22/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0093 - val_loss: 0.1116 - learning_rate: 0.0010
# Epoch 23/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0094 - val_loss: 0.0896 - learning_rate: 0.0010
# Epoch 24/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0099 - val_loss: 0.1127 - learning_rate: 0.0010
# Epoch 25/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0099 - val_loss: 0.1158 - learning_rate: 0.0010
# Epoch 26/100
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0089 - val_loss: 0.0790 - learning_rate: 0.0010
# Epoch 27/100
# 579/584 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0099 - val_loss: 0.0816 - learning_rate: 0.0010

# %%
# --- 결과 시각화 ---
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('MLP Train Loss with RUL Prediction')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### CNN 1D

# %%
def simplified_conv1d_model_without_lstm(input_shape):
    input_layer = Input(shape=input_shape)

    x = Conv1D(filters=16, kernel_size=5, activation='relu', kernel_regularizer=regularizers.l2(0.005), padding='causal')(input_layer)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.25)(x)

    x_flattened = Flatten()(x)

    output = Dense(1, activation='linear', kernel_regularizer=regularizers.l2(0.005))(x_flattened)

    model = Model(inputs=input_layer, outputs=output)
    return model

# %%
input_shape = X_train_final.shape[1:] # (total_features, 1)

model = simplified_conv1d_model_without_lstm(input_shape)

custom_adam_optimizer_1 = Adam(learning_rate=0.0001)
model.compile(optimizer=custom_adam_optimizer_1, loss='mse')
model.summary() # 모델 요약 출력

# 콜백 설정
early_stop = EarlyStopping(patience=7, restore_best_weights=True, monitor='val_loss')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=0.00001, verbose=1)

history = model.fit(
    X_train_final, y_train_final,
    batch_size=32,
    epochs=100,
    validation_split=0.1,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 320, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_13 (Conv1D)              │ (None, 320, 16)        │            96 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_13 (MaxPooling1D) │ (None, 160, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 160, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2560)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │         2,561 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,657 (10.38 KB)
#  Trainable params: 2,657 (10.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.1229 - val_loss: 0.2177 - learning_rate: 1.0000e-04
# Epoch 2/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0455 - val_loss: 0.3874 - learning_rate: 1.0000e-04
# Epoch 3/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0369 - val_loss: 0.4250 - learning_rate: 1.0000e-04
# Epoch 4/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0320 - val_loss: 0.4704 - learning_rate: 1.0000e-04
# Epoch 5/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0291 - val_loss: 0.4746 - learning_rate: 1.0000e-04
# Epoch 6/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0271 - val_loss: 0.4701 - learning_rate: 1.0000e-04
# Epoch 7/100
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0256 - val_loss: 0.4638 - learning_rate: 1.0000e-04
# Epoch 8/100
# 646/657 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0252
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0252 - val_loss: 0.4773 - learning_rate: 1.0000e-04

# %%
# --- 결과 시각화 ---
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('CNN Train Loss with RUL Prediction')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### CNN-LSTM simple version

# %%
def simplified_conv1d_lstm_model_v1(input_shape):
    input_layer = Input(shape=input_shape)

    x = Conv1D(filters=8, kernel_size=3, activation='relu', kernel_regularizer=regularizers.l2(0.005), padding='causal')(input_layer)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.2)(x)

    lstm_out = LSTM(16, return_sequences=False,kernel_regularizer=regularizers.l2(0.005))(x)
    dropout_lstm = Dropout(0.3)(lstm_out)

    output = Dense(1, activation='linear')(dropout_lstm)

    model = Model(inputs=input_layer, outputs=output)
    return model

# %%
input_shape = X_train_final.shape[1:] # (total_features, 1)

model = simplified_conv1d_lstm_model_v1(input_shape)

custom_adam_optimizer_1 = Adam(learning_rate=0.0001)
model.compile(optimizer=custom_adam_optimizer_1, loss='mse')
model.summary() # 모델 요약 출력

# 콜백 설정
early_stop = EarlyStopping(patience=7, restore_best_weights=True, monitor='val_loss')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=0.00001, verbose=1)

history = model.fit(
    X_train_final, y_train_final,
    batch_size=32,
    epochs=100,
    validation_split=0.1,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 320, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 320, 8)         │            32 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 160, 8)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 160, 8)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 16)             │         1,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,649 (6.44 KB)
#  Trainable params: 1,649 (6.44 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 46s 66ms/step - loss: 0.2148 - val_loss: 0.1079 - learning_rate: 1.0000e-04
# Epoch 2/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 80s 64ms/step - loss: 0.1037 - val_loss: 0.0593 - learning_rate: 1.0000e-04
# Epoch 3/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 43s 68ms/step - loss: 0.0814 - val_loss: 0.0537 - learning_rate: 1.0000e-04
# Epoch 4/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 40s 63ms/step - loss: 0.0705 - val_loss: 0.0448 - learning_rate: 1.0000e-04
# Epoch 5/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 43s 67ms/step - loss: 0.0643 - val_loss: 0.0370 - learning_rate: 1.0000e-04
# Epoch 6/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 80s 65ms/step - loss: 0.0599 - val_loss: 0.0340 - learning_rate: 1.0000e-04
# Epoch 7/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 81s 64ms/step - loss: 0.0592 - val_loss: 0.0331 - learning_rate: 1.0000e-04
# Epoch 8/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 42s 65ms/step - loss: 0.0586 - val_loss: 0.0321 - learning_rate: 1.0000e-04
# Epoch 9/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 84s 68ms/step - loss: 0.0580 - val_loss: 0.0348 - learning_rate: 1.0000e-04
# Epoch 10/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 80s 64ms/step - loss: 0.0556 - val_loss: 0.0274 - learning_rate: 1.0000e-04
# Epoch 11/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 41s 65ms/step - loss: 0.0557 - val_loss: 0.0252 - learning_rate: 1.0000e-04
# Epoch 12/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 82s 65ms/step - loss: 0.0549 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 13/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 83s 67ms/step - loss: 0.0538 - val_loss: 0.0284 - learning_rate: 1.0000e-04
# Epoch 14/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 41s 65ms/step - loss: 0.0530 - val_loss: 0.0231 - learning_rate: 1.0000e-04
# Epoch 15/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 82s 65ms/step - loss: 0.0527 - val_loss: 0.0280 - learning_rate: 1.0000e-04
# Epoch 16/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 82s 65ms/step - loss: 0.0517 - val_loss: 0.0198 - learning_rate: 1.0000e-04
# Epoch 17/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 81s 65ms/step - loss: 0.0497 - val_loss: 0.0273 - learning_rate: 1.0000e-04
# Epoch 18/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 83s 67ms/step - loss: 0.0489 - val_loss: 0.0189 - learning_rate: 1.0000e-04
# Epoch 19/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 81s 65ms/step - loss: 0.0475 - val_loss: 0.0139 - learning_rate: 1.0000e-04
# Epoch 20/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 84s 68ms/step - loss: 0.0491 - val_loss: 0.0322 - learning_rate: 1.0000e-04
# Epoch 21/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 79s 65ms/step - loss: 0.0465 - val_loss: 0.0135 - learning_rate: 1.0000e-04
# Epoch 22/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 82s 64ms/step - loss: 0.0472 - val_loss: 0.0153 - learning_rate: 1.0000e-04
# Epoch 23/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 41s 65ms/step - loss: 0.0469 - val_loss: 0.0199 - learning_rate: 1.0000e-04
# Epoch 24/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 84s 68ms/step - loss: 0.0469 - val_loss: 0.0049 - learning_rate: 1.0000e-04
# Epoch 25/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 91s 81ms/step - loss: 0.0453 - val_loss: 0.0142 - learning_rate: 1.0000e-04
# Epoch 26/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 71s 64ms/step - loss: 0.0455 - val_loss: 0.0148 - learning_rate: 1.0000e-04
# Epoch 27/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 42s 65ms/step - loss: 0.0458 - val_loss: 0.0297 - learning_rate: 1.0000e-04
# Epoch 28/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 84s 68ms/step - loss: 0.0452 - val_loss: 0.0260 - learning_rate: 1.0000e-04
# Epoch 29/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 80s 65ms/step - loss: 0.0457 - val_loss: 0.0294 - learning_rate: 1.0000e-04
# Epoch 30/100
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 81s 64ms/step - loss: 0.0451 - val_loss: 0.0121 - learning_rate: 1.0000e-04
# Epoch 31/100
# 635/636 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0450
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 636/636 ━━━━━━━━━━━━━━━━━━━━ 82s 65ms/step - loss: 0.0450 - val_loss: 0.0114 - learning_rate: 1.0000e-04

# %%
# --- 결과 시각화 ---
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('simple CNN-LSTM Train Loss with RUL Prediction')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## 모델 저장

# %%
# Google Drive 내에 저장할 디렉토리 경로
save_path = "/content/drive/MyDrive/KSPHM-data-challenge/model"
os.makedirs(save_path, exist_ok=True)

# 모델 저장
model.save(os.path.join(save_path, "simple_cnn_lstm_model_FE.h5"))

print("모델이 'simple_cnn_lstm_model_FE.h5'에 성공적으로 저장되었습니다.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 모델이 'simple_cnn_lstm_model_FE.h5'에 성공적으로 저장되었습니다.
